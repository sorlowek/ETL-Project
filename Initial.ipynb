# %% [markdown]
# # Extract Transform Load Project (ETL)

# %% [markdown]
# # Extracting Original data sources

# %%
import os
import utm
import pandas as pd
import matplotlib.pyplot as plt
import sqlalchemy
from sqlalchemy import create_engine
from sqlalchemy.orm import Session
import reverse_geocoder as rg
import pprint

# %%
csv_file = "./Data Files/CWD_Surveillance_data_2000_2010.csv"
cwd_2000_2010_df = pd.read_csv(csv_file)
cwd_2000_2010_df.head()
# Out:
#    Case_ID      Province Harvest Type       ObsDate     Month_Obs  Year_Obs  \
# 0      100  Saskatchewan       Hunter  Undetermined  Undetermined      2000
# 1      101  Saskatchewan       Hunter  Undetermined  Undetermined      2001
# 2      102  Saskatchewan       Hunter  Undetermined  Undetermined      2002
# 3      103  Saskatchewan       Hunter  Undetermined  Undetermined      2003
# 4      104  Saskatchewan       Hunter  Undetermined  Undetermined      2004
#
#     Easting   Northing    Species     Sex CWD Status
# 0  580000.0  5850000.0  Mule Deer    Male   Positive
# 1  580000.0  5830000.0  Mule Deer    Male   Positive
# 2  570000.0  5830000.0  Mule Deer    Male   Positive
# 3  610000.0  5950000.0  Mule Deer  Female   Positive
# 4  590000.0  5840000.0  Mule Deer    Male   Positive

# %%
cwd_2000_2010_df['Province'].value_counts()
# Out:
# Alberta         16330
# Saskatchewan     3222
# Name: Province, dtype: int64

# %%
csv_file = "./Data Files/Census_Data.csv"
census_data_df = pd.read_csv(csv_file)
census_data_df
# Out:
#                      Province      Population
# 0   Newfoundland and Labrador     155,304.00
# 1        Prince Edward Island      57,887.00
# 2                 Nova Scotia     512,612.00
# 3               New Brunswick     195,361.00
# 4                      Quebec   3,064,452.00
# 5                     Ontario   5,255,754.00
# 6                    Manitoba     723,747.00
# 7                Saskatchewan     450,418.00
# 8                     Alberta   2,001,524.00
# 9                       Yukon      23,276.00
# 10                Yellowknife      19,234.00
# 11                    Nunavut           6,699

# %%
csv_file = "./Data Files/CWD_surveillance_validation_data_2011_2013.csv"
cwd_2011_2013_df = pd.read_csv(csv_file)
cwd_2011_2013_df.head()
# Out:
#     Case  Year  Easting  Northing CWD_Status            Species     Sex
# 0  10000  2011   432845   5849162   Negative  White-tailed Deer    Male
# 1  10001  2011   429500   5868700   Negative  White-tailed Deer    Male
# 2  10002  2011   438723   5896022   Negative  White-tailed Deer    Male
# 3  10003  2011   428623   5862820   Negative          Mule Deer    Male
# 4  10004  2011   431230   5882820   Negative          Mule Deer  Female

# %% [markdown]
# # Transform: What data cleaning or transformation was required.

# %%
new_cwd_2000_2010_df = cwd_2000_2010_df[['Case_ID', 'Province', 'Year_Obs', 'Species', 'Sex', 'CWD Status']].copy()
new_cwd_2000_2010_df.head()
# Out:
#    Case_ID      Province  Year_Obs    Species     Sex CWD Status
# 0      100  Saskatchewan      2000  Mule Deer    Male   Positive
# 1      101  Saskatchewan      2001  Mule Deer    Male   Positive
# 2      102  Saskatchewan      2002  Mule Deer    Male   Positive
# 3      103  Saskatchewan      2003  Mule Deer  Female   Positive
# 4      104  Saskatchewan      2004  Mule Deer    Male   Positive

# %%
new_cwd_2000_2010_df = new_cwd_2000_2010_df.rename(columns={"Year_Obs":"Year", "CWD Status":"CWD_Status"})
new_cwd_2000_2010_df.head()
# Out:
#    Case_ID      Province  Year    Species     Sex CWD_Status
# 0      100  Saskatchewan  2000  Mule Deer    Male   Positive
# 1      101  Saskatchewan  2001  Mule Deer    Male   Positive
# 2      102  Saskatchewan  2002  Mule Deer    Male   Positive
# 3      103  Saskatchewan  2003  Mule Deer  Female   Positive
# 4      104  Saskatchewan  2004  Mule Deer    Male   Positive

# %%
new_deer_2000_2010_df = new_cwd_2000_2010_df.drop(['Year'], axis=1)
new_deer_2000_2010_df.head()
# Out:
#    Case_ID      Province    Species     Sex CWD_Status
# 0      100  Saskatchewan  Mule Deer    Male   Positive
# 1      101  Saskatchewan  Mule Deer    Male   Positive
# 2      102  Saskatchewan  Mule Deer    Male   Positive
# 3      103  Saskatchewan  Mule Deer  Female   Positive
# 4      104  Saskatchewan  Mule Deer    Male   Positive

# %%
cwd_2011_2013_df = cwd_2011_2013_df.rename(columns={"Case":"Case_ID"})
cwd_2011_2013_df.head()
# Out:
#    Case_ID  Year  Easting  Northing CWD_Status            Species     Sex
# 0    10000  2011   432845   5849162   Negative  White-tailed Deer    Male
# 1    10001  2011   429500   5868700   Negative  White-tailed Deer    Male
# 2    10002  2011   438723   5896022   Negative  White-tailed Deer    Male
# 3    10003  2011   428623   5862820   Negative          Mule Deer    Male
# 4    10004  2011   431230   5882820   Negative          Mule Deer  Female

# %%
utm.to_latlon(548750.7613, 5826273.207, 12, "N")
# Out:
# (52.584309997959735, -110.28045998665556)

# %%
#easting = []
#northing = []
#latitude = []
#longitude = []
#address = []
#province =[]

#easting = cwd_2011_2013_df["Easting"]
#northing = cwd_2011_2013_df["Northing"]

#for i in range(0, len(easting)):
   #latlong = utm.to_latlon(easting[i], northing[i], 12, "N")


   #def reverseGeocode(latlong):
     #result = rg.search(latlong)
     #address.append(result)
    
   #if __name__=="__main__":
     #reverseGeocode(latlong)

   #province.append(address[i][0]["admin1"])

# %%
#cwd_2011_2013_df['Province']= province

#cwd_2011_2013_df

# %%
#cwd_2011_2013_df.to_csv('deer_data_2011-2013.csv')

# %%
csv_file = "./Data Files/deer_data_2011-2013.csv"
deer_data_2011_2013_df = pd.read_csv(csv_file)
deer_data_2011_2013_df
# Out:
#       Unnamed: 0  Case_ID  Year  Easting  Northing CWD_Status  \
# 0              0    10000  2011   432845   5849162   Negative
# 1              1    10001  2011   429500   5868700   Negative
# 2              2    10002  2011   438723   5896022   Negative
# 3              3    10003  2011   428623   5862820   Negative
# 4              4    10004  2011   431230   5882820   Negative
# 5              5    10005  2011   444623   5897822   Negative
# 6              6    10006  2011   428592   5872368   Negative
# 7              7    10007  2011   445655   5870519   Negative
# 8              8    10008  2011   430831   5881672   Negative
# 9              9    10009  2011   430200   5867300   Negative
# 10            10    10010  2011   426423   5857920   Negative
# 11            11    10011  2011   438723   5896022   Negative
# 12            12    10012  2011   430131   5867041   Negative
# 13            13    10013  2011   469823   5811220   Negative
# 14            14    10014  2011   655418   5911974   Negative
# 15            15    10015  2011   517933   5797196   Negative
# 16            16    10016  2011   483198   5858918   Negative
# 17            17    10017  2011   496680   5806873   Negative
# 18            18    10018  2011   507624   5852417   Negative
# 19            19    10019  2011   507624   5852417   Negative
# 20            20    10020  2011   646604   5907662   Negative
# 21            21    10021  2011   553529   5619920   Negative
# 22            22    10022  2011   524861   5785903   Negative
# 23            23    10023  2011   478683   5896985   Negative
# 24            24    10024  2011   478683   5896985   Negative
# 25            25    10025  2011   564599   5490117   Negative
# 26            26    10026  2011   495427   5685170   Negative
# 27            27    10027  2011   489736   5653943   Negative
# 28            28    10028  2011   545015   5489893   Negative
# 29            29    10029  2011   565792   5645520   Negative
# 9313          Mule Deer  Female       Alberta
# 9314          Mule Deer    Male       Alberta
# 9315  White-tailed Deer    Male       Alberta
# 9316          Mule Deer    Male       Alberta
# 9317          Mule Deer    Male       Alberta
# 9318          Mule Deer  Female       Alberta
# 9319          Mule Deer    Male       Alberta
# 9320          Mule Deer    Male       Alberta
# 9321          Mule Deer  Female       Alberta
# 9322          Mule Deer    Male       Alberta
# 9323          Mule Deer    Male       Alberta
# 9324          Mule Deer    Male       Alberta
# 9325          Mule Deer    Male       Alberta
# 9326          Mule Deer  Female       Alberta
# 9327          Mule Deer    Male       Alberta
#
# [9328 rows x 9 columns]

# %%
#No longer need these columns and must remove to append.
new_deer_2011_2013_df = deer_data_2011_2013_df.drop(['Easting', 'Unnamed: 0','Northing','Year'], axis=1)
new_deer_2011_2013_df.head()
# Out:
#    Case_ID CWD_Status            Species     Sex Province
# 0    10000   Negative  White-tailed Deer    Male  Alberta
# 1    10001   Negative  White-tailed Deer    Male  Alberta
# 2    10002   Negative  White-tailed Deer    Male  Alberta
# 3    10003   Negative          Mule Deer    Male  Alberta
# 4    10004   Negative          Mule Deer  Female  Alberta

# %%
#Appending the two DataFrames together into one so the new transformed file is ready to load into SQL.
cwd_2000_2013_df = new_deer_2000_2010_df.append(new_deer_2011_2013_df)
cwd_2000_2013_df.head()
# Out:
# /Users/stevencantor/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:6701: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
#   CWD_Status  Case_ID      Province     Sex    Species
# 0   Positive      100  Saskatchewan    Male  Mule Deer
# 1   Positive      101  Saskatchewan    Male  Mule Deer
# 2   Positive      102  Saskatchewan    Male  Mule Deer
# 3   Positive      103  Saskatchewan  Female  Mule Deer
# 4   Positive      104  Saskatchewan    Male  Mule Deer

# %%
#Checking Data
cwd_2000_2013_df.tail()
# Out:
#      CWD_Status  Case_ID Province     Sex    Species
# 9323   Positive    19323  Alberta    Male  Mule Deer
# 9324   Positive    19324  Alberta    Male  Mule Deer
# 9325   Positive    19325  Alberta    Male  Mule Deer
# 9326   Positive    19326  Alberta  Female  Mule Deer
# 9327   Positive    19327  Alberta    Male  Mule Deer

# %%
#Checking Datab
cwd_2000_2013_df['Province'].value_counts()
# Out:
# Alberta                  24947
# Saskatchewan              3822
# Montana                    110
# Northwest Territories        1
# Name: Province, dtype: int64

# %%
#Saving our combined data.
cwd_2000_2013_df.to_csv('./Data Files/2000_2013.csv')

# %% [markdown]
# # Load: the final database, tables/collections.

# %%
rds_connection_string = "root:ssmysqlpass@127.0.0.1/deer_db"
engine = create_engine(f'mysql://{rds_connection_string}')

# %%
session=Session(engine)

# %%
engine.table_names()
# Out:
# ['census', 'deercwd']

# %%
cwd_2000_2013_df.to_sql(name='deercwd', con=engine, if_exists='append', index=False)

# %%
census_data_df.to_sql(name='census', con=engine, if_exists='append', index=False)

# %%
pd.read_sql_query('select * from deercwd', con=engine).head()
# Out:
#    id      province  case_id    species     sex cwd_status
# 0   1  Saskatchewan      100  Mule Deer    Male   Positive
# 1   2  Saskatchewan      101  Mule Deer    Male   Positive
# 2   3  Saskatchewan      102  Mule Deer    Male   Positive
# 3   4  Saskatchewan      103  Mule Deer  Female   Positive
# 4   5  Saskatchewan      104  Mule Deer    Male   Positive

# %%
pd.read_sql_query('select * from census', con=engine).head()
# Out:
#    id                   province      population
# 0   1  Newfoundland and Labrador     155,304.00
# 1   2       Prince Edward Island      57,887.00
# 2   3                Nova Scotia     512,612.00
# 3   4              New Brunswick     195,361.00
# 4   5                     Quebec   3,064,452.00
